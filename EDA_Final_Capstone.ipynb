# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

# %%
df = pd.read_csv("/content/drive/MyDrive/Final_Capstone/RFS_cleaned_data.csv")

# %%
df
# Out:
#         Store  Dept  IsHoliday  Temperature  Fuel_Price  Day  Month  Year  \
# 0           1     1          0        42.31       2.572    5      2  2010
# 1           1     2          0        42.31       2.572    5      2  2010
# 2           1     3          0        42.31       2.572    5      2  2010
# 3           1     4          0        42.31       2.572    5      2  2010
# 4           1     5          0        42.31       2.572    5      2  2010
# ...       ...   ...        ...          ...         ...  ...    ...   ...
# 551474     45    94          0        76.06       3.804   26      7  2013
# 551475     45    95          0        76.06       3.804   26      7  2013
# 551476     45    96          0        76.06       3.804   26      7  2013
# 551477     45    97          0        76.06       3.804   26      7  2013
# 551478     45    98          0        76.06       3.804   26      7  2013
#
#         Type    Size  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0          1  151315  5797.7752  6409.2456   145.3908  24112.552  4611.1169
# 1          1  151315  5797.7752  6409.2456   145.3908  24112.552  4611.1169
# 2          1  151315  5797.7752  6409.2456   145.3908  24112.552  4611.1169
# 3          1  151315  5797.7752  6409.2456   145.3908  24112.552  4611.1169
# 4          1  151315  5797.7752  6409.2456   145.3908  24112.552  4611.1169
# ...      ...     ...        ...        ...        ...        ...        ...
# 551474     2  118221   212.0200  1251.2600     2.0600     10.880  1864.5700
# 551475     2  118221   212.0200  1251.2600     2.0600     10.880  1864.5700
# 551476     2  118221   212.0200  1251.2600     2.0600     10.880  1864.5700
# 551477     2  118221   212.0200  1251.2600     2.0600     10.880  1864.5700
# 551478     2  118221   212.0200  1251.2600     2.0600     10.880  1864.5700
#
#                CPI  Unemployment  Weekly_Sales
# 0       211.096358         8.106    24924.5000
# 1       211.122158         8.106    50605.2700
# 2       211.096358         8.106    13740.1200
# 3       211.122158         8.106    39954.0400
# 4       211.096358         8.106    32229.3800
# ...            ...           ...           ...
# 551474  132.473333         8.625     3326.5400
# 551475  132.473333         8.625    61087.7479
# 551476  132.473333         8.625     3033.3741
# 551477  132.473333         8.625     5779.7721
# 551478  132.473333         8.625     1037.9059
#
# [551479 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Store', 'Dept', 'IsHoliday', 'Temperature', 'Fuel_Price', 'Day',
#        'Month', 'Year', 'Type', 'Size', 'MarkDown1', 'MarkDown2', 'MarkDown3',
#        'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'Weekly_Sales'],
#       dtype='object')

# %%
x = df.query("IsHoliday ==1")

x =x [['Store', 'Dept', 'IsHoliday',
       'Month', 'Year', 'Type', 'Size', 'MarkDown1', 'MarkDown2', 'MarkDown3',
       'MarkDown4', 'MarkDown5','Weekly_Sales']]

# %%
x
# Out:
#         Store  Dept  IsHoliday  Month  Year  Type    Size   MarkDown1  \
# 73          1     1          1      2  2010     1  151315  67488.4155
# 74          1     2          1      2  2010     1  151315  67488.4155
# 75          1     3          1      2  2010     1  151315  67488.4155
# 76          1     4          1      2  2010     1  151315  67488.4155
# 77          1     5          1      2  2010     1  151315  67488.4155
# ...       ...   ...        ...    ...   ...   ...     ...         ...
# 549698     45    94          1      2  2013     2  118221  53311.8800
# 549699     45    95          1      2  2013     2  118221  53311.8800
# 549700     45    96          1      2  2013     2  118221  53311.8800
# 549701     45    97          1      2  2013     2  118221  53311.8800
# 549702     45    98          1      2  2013     2  118221  53311.8800
#
#         MarkDown2  MarkDown3   MarkDown4  MarkDown5  Weekly_Sales
# 73      6409.2456    98.9397  10730.6477  4399.0955    46039.4900
# 74      6409.2456    98.9397  10730.6477  4399.0955    44682.7400
# 75      6409.2456    98.9397  10730.6477  4399.0955    10887.8400
# 76      6409.2456    98.9397  10730.6477  4399.0955    35351.2100
# 77      6409.2456    98.9397  10730.6477  4399.0955    29620.8100
# ...           ...        ...         ...        ...           ...
# 549698  5131.8100    78.2600  24823.9400  3233.4400     3366.1664
# 549699  5131.8100    78.2600  24823.9400  3233.4400    55206.4974
# 549700  5131.8100    78.2600  24823.9400  3233.4400     1492.5605
# 549701  5131.8100    78.2600  24823.9400  3233.4400     6275.9740
# 549702  5131.8100    78.2600  24823.9400  3233.4400      922.8188
#
# [39654 rows x 13 columns]

# %%
x.columns
# Out:
# Index(['Store', 'Dept', 'IsHoliday', 'Month', 'Year', 'Type', 'Size',
#        'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5',
#        'Weekly_Sales'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.heatmap(x.corr(), annot=True, cmap='Blues',fmt='.2f')
plt.title("Correlation")
plt.show()

# %% [markdown]
# ###**Unique_Values_Of_Features**

# %%
def unique_values(columns):
  print(f'Total Rows Count:{df.shape[0]}')
  print()
  for i in columns:
    print(f'{i}:{df[i].nunique()}')
    print()

unique_values(df.select_dtypes(include='number'))
# Out:
# Total Rows Count:551479
#
# Store:45
#
# Dept:81
#
# IsHoliday:2
#
# Temperature:4178
#
# Fuel_Price:1011
#
# Day:31
#
# Month:12
#
# Year:4
#
# Type:3
#
# Size:40
#
# MarkDown1:8617
#
# MarkDown2:7742
#
# MarkDown3:8016
#
# MarkDown4:8839
#
# MarkDown5:8381
#
# CPI:6522
#
# Unemployment:899
#
# Weekly_Sales:490072

# %% [markdown]
# ###**Summary Statistics**

# %%
df.describe().T
# Out:
#                  count           mean           std        min           25%  \
# Store         551479.0      22.270485     12.796872      1.000     11.000000
# Dept          551479.0      44.603013     30.416079      1.000     19.000000
# IsHoliday     551479.0       0.071905      0.258330      0.000      0.000000
# Temperature   551479.0      58.703624     18.685408     -7.290     45.160000
# Fuel_Price    551479.0       3.413010      0.427725      2.472      3.050000
# Day           551479.0      15.653488      8.776044      1.000      8.000000
# Month         551479.0       6.277180      3.340134      1.000      3.000000
# Year          551479.0    2011.392758      1.054086   2010.000   2010.000000
# Type          551479.0       1.594791      0.669624      1.000      1.000000
# Size          551479.0  136073.691863  61207.331445  34875.000  93638.000000
# MarkDown1     551479.0    7106.908987   7995.063578  -2781.450   2516.328200
# MarkDown2     551479.0    3490.155469   8633.406252   -265.760     72.760100
# MarkDown3     551479.0    1262.550752   9360.987950   -179.260     11.090000
# MarkDown4     551479.0    3256.614033   6441.450462      0.220    272.510000
# MarkDown5     551479.0    4798.673278  11234.044679   -185.170   2049.940000
# CPI           551479.0     177.231413     40.701721    126.064    132.716097
# Unemployment  551479.0       7.715673      1.853732      3.684      6.560000
# Weekly_Sales  551479.0   15727.461007  22649.795576      1.000   1862.325000
#
#                         50%            75%            max
# Store             22.000000      33.000000      45.000000
# Dept              38.000000      74.000000      99.000000
# IsHoliday          0.000000       0.000000       1.000000
# Temperature       59.940000      73.160000     101.950000
# Fuel_Price         3.524000       3.746000       4.468000
# Day               16.000000      23.000000      31.000000
# Month              6.000000       9.000000      12.000000
# Year            2011.000000    2012.000000    2013.000000
# Type               1.000000       2.000000       3.000000
# Size          128107.000000  202505.000000  219622.000000
# MarkDown1       5557.664700    8833.723200  103184.980000
# MarkDown2        311.250400    2540.069000  104519.540000
# MarkDown3         40.280000     118.994700  149483.310000
# MarkDown4       1256.003200    3355.690000   67474.850000
# MarkDown5       3514.328500    5506.728000  771448.100000
# CPI              191.344886     216.213699     228.976456
# Unemployment       7.706000       8.523000      14.313000
# Weekly_Sales    7308.850000   19903.976000  693099.360000

# %% [markdown]
# ### Pearson Correlation Coefficient
#  Here we will do statistic measure  to find strength and direction  of the linear relationship b.w two continous  variable
#
# Range : ( -1 to 1 )
#
#       # value close to 1 means positive correlation if x increase y also increases and vice versa
#
#       # value close to -1 means negative correlation if x increase  y  will decrease and vice versa
#
#       # value close to 0  means no linear relationship

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(),annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation')
plt.show()

# %%
correlation_matrix = spearmanr(df.select_dtypes(include=np.number)) # Extract the correlation matrix
correlation_coefficients = correlation_matrix[0]
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_coefficients, annot=True, cmap='coolwarm', fmt='.2f', xticklabels=df.columns, yticklabels=df.columns)
plt.title('Spearman\'s Rank Correlation Heatmap')
plt.title('Correlation')
plt.show()

# %% [markdown]
# ### **Inshights**
# ## Store and Department
# #### which Top 10 stores has highest weekly sales?

# %%
mean_sales = df.groupby(['Store']).agg({'Weekly_Sales': 'sum'}).reset_index()

z = mean_sales.nlargest(10,'Weekly_Sales').values.tolist()

data = {}
for i in z:
  data.update({i[0]:i[1]})

sorted_data = dict(sorted(data.items(), key = lambda item : item[1],reverse = True))
sorted_data
# Out:
# {20.0: 384717199.9312,
#  4.0: 384545825.2873,
#  13.0: 369637803.5805,
#  14.0: 363818514.0407,
#  2.0: 353739243.7851,
#  10.0: 342671002.0564,
#  27.0: 322386258.2559,
#  6.0: 287380329.6357,
#  1.0: 285833706.838,
#  39.0: 268982317.012}

# %%
plt.figure(figsize = (12,8))
sns.barplot(x=[i for i in sorted_data.keys()],y=[i for i in sorted_data.values()], palette = 'viridis').set(title = 'Top 10 stores has highest Weekly Sales',xlabel='Store',ylabel= 'values')
plt.show()
# Out:
# <ipython-input-35-e757522d799f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=[i for i in sorted_data.keys()],y=[i for i in sorted_data.values()], palette = 'viridis').set(title = 'Top 10 stores has highest Weekly Sales',xlabel='Store',ylabel= 'values')

# %% [markdown]
# ### Which top 10 store has lowest weekly sales?

# %%
mean_sales = df.groupby(['Store']).agg({'Weekly_Sales':'sum'}).reset_index()

z = mean_sales.nsmallest(10,'Weekly_Sales').values.tolist()

data = {}
for i in z:
  data.update({i[0]:i[1]})

  sorted_data = dict(sorted(data.items(), key = lambda item : item[1],reverse = True))
sorted_data

plt.figure(figsize = (12,8))
sns.barplot(x=[i for i in sorted_data.keys()],y=[i for i in sorted_data.values()], palette = 'viridis').set(title = 'Top 10 stores has lowest Weekly Sales',xlabel='Store',ylabel= 'values')
plt.show()
# Out:
# <ipython-input-36-b012e9da8eef>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=[i for i in sorted_data.keys()],y=[i for i in sorted_data.values()], palette = 'viridis').set(title = 'Top 10 stores has lowest Weekly Sales',xlabel='Store',ylabel= 'values')

# %% [markdown]
# ### What is the average weekly sales for each store and department
# #### Top 10 store and separtment combination

# %%
mean_sales = df.groupby(['Store','Dept'])['Weekly_Sales'].mean().reset_index()
mean_sales = mean_sales.sort_values(by = 'Weekly_Sales',ascending=False).nlargest(10,'Weekly_Sales').reset_index(drop=True)

# %%
mean_sales
# Out:
#    Store  Dept   Weekly_Sales
# 0     14    92  180155.540448
# 1      2    92  167859.394648
# 2     20    92  166557.573785
# 3     13    92  165741.572390
# 4      4    92  161923.858886
# 5     20    95  149483.195648
# 6      4    95  147658.726760
# 7     27    92  146484.855359
# 8      2    95  143193.446280
# 9     14    95  142167.864556

# %% [markdown]
# #### Top 10 lowest store and department combination

# %%
mean_sales = df.groupby(['Store','Dept'])['Weekly_Sales'].mean().reset_index()
mean_sales.nsmallest(10,'Weekly_Sales').reset_index(drop=True)
# Out:
#    Store  Dept  Weekly_Sales
# 0     33    44      4.988170
# 1     42    44      5.290977
# 2     43    44      5.887533
# 3     37    44      6.093398
# 4     36    44      7.258327
# 5     38    44      7.312635
# 6     30    44      7.550400
# 7     36    52      7.883220
# 8     45    51      9.177095
# 9     24    51      9.455238

# %% [markdown]
# ### What are the Departments Perform Better In Specific Store Types?

# %%
mention_store_type = int(input('Enter The Store Type:'))
performance_in_store_types = df.query(f'Type == {mention_store_type}')
performance_in_store_types = performance_in_store_types.groupby(['Store','Dept'])['Weekly_Sales'].mean().reset_index()
performance_in_store_types.nlargest(10,'Weekly_Sales').reset_index(drop=True)
# Out:
# Enter The Store Type:1
#    Store  Dept   Weekly_Sales
# 0     14    92  180155.540448
# 1      2    92  167859.394648
# 2     20    92  166557.573785
# 3     13    92  165741.572390
# 4      4    92  161923.858886
# 5     20    95  149483.195648
# 6      4    95  147658.726760
# 7     27    92  146484.855359
# 8      2    95  143193.446280
# 9     14    95  142167.864556

# %% [markdown]
# ### What are the Departments Not Performing Better In Specific Store Types?

# %%
mention_store_type = int(input('Enter The Store Type:'))
performance_in_store_types = df.query(f'Type == {mention_store_type}')
performance_in_store_types = performance_in_store_types.groupby(['Store','Dept'])['Weekly_Sales'].mean().reset_index()
performance_in_store_types.nsmallest(10, 'Weekly_Sales')
# Out:
# Enter The Store Type:1
#       Store  Dept  Weekly_Sales
# 1273     33    44      4.988170
# 1413     36    44      7.258327
# 1416     36    52      7.883220
# 823      24    51      9.455238
# 1415     36    49     10.071039
# 1275     33    49     11.737780
# 1486     39    51     15.211195
# 1276     33    52     15.898751
# 1130     31    51     16.848048
# 900      26    51     17.228508

# %% [markdown]
# ###**Time Analysis**

# %%
sns.lineplot(x='Year',y='Weekly_Sales',data=df, color = 'r')
plt.title('Yearly Sales')
plt.xlabel('Year')
plt.ylabel('Weekly Sales')
plt.show()

# %% [markdown]
# ### Do sales tend to be higher on Holidays?

# %%
df.IsHoliday.unique()
# Out:
# array([0, 1])

# %%
df.IsHoliday = df.IsHoliday.map({0:'False',1:'True'})

# %%
df.IsHoliday.unique()
# Out:
# array(['False', 'True'], dtype=object)

# %%
data = df.groupby(['IsHoliday','Year'])['Weekly_Sales'].sum().reset_index()
data
# Out:
#   IsHoliday  Year  Weekly_Sales
# 0     False  2010  2.088979e+09
# 1     False  2011  2.241704e+09
# 2     False  2012  2.276063e+09
# 3     False  2013  1.387934e+09
# 4      True  2010  2.002500e+08
# 5      True  2011  2.067491e+08
# 6      True  2012  2.212852e+08
# 7      True  2013  5.040101e+07

# %%
sns.barplot(data = data, x = 'Year', y = 'Weekly_Sales', hue = 'IsHoliday')
plt.title('Holiday weeks vs Non Holiday weeks')
plt.xlabel('Year')
plt.ylabel('Weekly Sales')
plt.savefig('Holiday.png',dpi = 300)
plt.show()

# %% [markdown]
# ## What is the distribution of weekly sales across different months?

# %%
data = df.groupby('Month')['Weekly_Sales'].sum().reset_index().nlargest(12,'Weekly_Sales')
data
# Out:
#     Month  Weekly_Sales
# 6       7  8.446743e+08
# 3       4  8.380944e+08
# 2       3  8.355010e+08
# 5       6  8.178054e+08
# 11     12  7.999891e+08
# 4       5  7.998159e+08
# 1       2  7.627062e+08
# 10     11  6.868833e+08
# 7       8  6.131726e+08
# 9      10  5.848391e+08
# 8       9  5.788785e+08
# 0       1  5.110046e+08

# %%
sns.barplot(data = data, x = 'Month', y = 'Weekly_Sales')
plt.title('Distribution of weekly sales on month')
plt.xlabel('Month')
plt.ylabel('Weekly Sales')
plt.savefig('Monthly.png',dpi = 300)
plt.show()

# %% [markdown]
# ##### Note : December Month has got the highest weekly sales in overall year
# ##### Note : All the Week Of Day Comes only in Friday

# %% [markdown]
# ## **Markdowns and Promotionst**
# ##### How do markdowns (markdown1, markdown2, markdown3, markdown4, markdown5) correlate with weekly sales?

# %%
plt.figure(figsize=(5,5))

sns.heatmap(df[['MarkDown1',	'MarkDown2',	'MarkDown3',	'MarkDown4',	'MarkDown5','Weekly_Sales'	]].corr(),annot=True,cmap='coolwarm', fmt='.2f')

plt.title('Correlation B.W Markdown and Weekly Sales')

plt.show()

# %%
c = df [['MarkDown1',	'MarkDown2',	'MarkDown3',	'MarkDown4',	'MarkDown5','Weekly_Sales'	]]
confusion_matrix,_ = spearmanr(c)
plt.figure(figsize=(5,5))
sns.heatmap(confusion_matrix,annot=True,cmap='coolwarm', fmt='.2f', xticklabels=c.columns, yticklabels=c.columns)
plt.title('Correlation B.W Markdown and Weekly Sales')
plt.show()

# %% [markdown]
# ### Economic Indicators
# #### Is there a relationship between the Consumer Price Index (CPI) and weekly sales?

# %%
df[['Weekly_Sales','CPI']].corr()
# Out:
#               Weekly_Sales       CPI
# Weekly_Sales      1.000000  0.053962
# CPI               0.053962  1.000000

# %%
sns.scatterplot(data=df , x ='CPI',y='Weekly_Sales')

plt.show()

# %% [markdown]
# ### what is the mean customer price index on every year?

# %%
mean_cpi = df.groupby('Year')['CPI'].mean().reset_index()
data = mean_cpi.nlargest(10,'CPI').reset_index(drop=True)
data
# Out:
#    Year         CPI
# 0  2010  179.322212
# 1  2011  176.785336
# 2  2012  176.683055
# 3  2013  175.836847

# %%
sns.barplot(data = data, x = 'Year', y = 'CPI')
plt.title('CPI Over Year')
plt.show()

# %% [markdown]
# ### What is mean unemployment over years

# %%
mean_cpi = df.groupby('Year')['Unemployment'].mean().reset_index()
data = mean_cpi.nlargest(10,'Unemployment').reset_index(drop=True)
sns.barplot(data = data, x = 'Year', y = 'Unemployment')
plt.title('Unemployment Over Year')
plt.show()

# %% [markdown]
# ### Specific Store CPI Trend

# %%
store_no = int(input('Enter the Store Number:'))
print()

query_data = df.query(f'Store == {store_no}')
sns.lineplot(data = query_data, x = 'Year', y = 'CPI', color='g')
plt.title(f'Specific Store {store_no} CPI Trend')
plt.show()
# Out:
# Enter the Store Number:1

# %% [markdown]
# ### Holidays and Special Events
# #### How do holidays impact weekly sales Over Year

# %%
sns.barplot(data = df, x = 'Year', y = 'Weekly_Sales', hue = 'IsHoliday')
plt.title('Weekly Sales impact on holidays over year')
plt.show()

# %%
sns.heatmap(df[['Weekly_Sales','IsHoliday']].corr(), annot = True)
plt.title('Correlation')
plt.show()

# %% [markdown]
# ### What are the stores has got higher sales in holidays?

# %%
plt.figure(figsize=(15,10))
sns.barplot(data = df, x = 'Store', y = 'Weekly_Sales', hue = 'IsHoliday')
plt.title('Stores has got higher sales in holidays')
plt.show()

# %% [markdown]
# ### Correlation Of Holiday B.W Markdown

# %%
df.IsHoliday.unique()
# Out:
# array([0, 1])

# %%
plt.figure(figsize = (5,5))
sns.heatmap(df[['MarkDown1',	'MarkDown2',	'MarkDown3',	'MarkDown4',	'MarkDown5','IsHoliday']].corr(),annot=True,cmap='coolwarm', fmt='.2f')
plt.title('Correlation B.W Markdown and Holiday')
plt.show()

# %%
c = df[['MarkDown1',	'MarkDown2',	'MarkDown3',	'MarkDown4',	'MarkDown5','IsHoliday'	]]

confusion_matrix , _ = spearmanr(c)

plt.figure(figsize=(5,5))

sns.heatmap(confusion_matrix,annot=True,cmap='coolwarm', fmt='.2f', xticklabels=c.columns, yticklabels=c.columns)

plt.title('Correlation B.W Markdown and IsHoliday')

plt.show()

# %% [markdown]
# ### **Store Factors**
# #### Does store size correlate with weekly sales?

# %%
sns.heatmap(df[['Weekly_Sales','Size']].corr(),annot = True)
plt.title('Correlation')
plt.show()

# %% [markdown]
# ## Impact of large store size

# %%
plt.figure(figsize=(15,10))
sns.barplot(data = df, x = 'Size', y = 'Weekly_Sales',hue = 'Size')
plt.title('Impact of large store size')
plt.show()

# %% [markdown]
# ## Weekly sales Impact On Store Types

# %%
sns.barplot(data = df, x = 'Type', y = 'Weekly_Sales', hue = 'Type')
plt.title('Weekly sales Impact On Store Types')
plt.show()

# %% [markdown]
# ## Weather and Temperature
# ### Is there a correlation between temperature and weekly sales?

# %%
sns.heatmap(df[['Temperature','Weekly_Sales']].corr(),annot=True)

plt.title('Correlation')

plt.show()

# %% [markdown]
# ### Do sales tend to increase during certain weather conditions?

# %%
sns.lineplot(data=df,x='Temperature',y='Weekly_Sales')

plt.show()

# %% [markdown]
# ### Sales Trends Over Time
# #### How have weekly sales evolved over time for specific departments?

# %%
department_no = int(input('Enter The Dept Number : '))
print()

query_data = df.query(f'Dept=={department_no}')

sns.lineplot(data=query_data, x='Year', y='Weekly_Sales')

plt.title(f'{department_no} department weekly sales Trend')

plt.show()
# Out:
# Enter The Dept Number : 2

# %% [markdown]
# ### How have weekly sales evolved over time for specific store and departments?

# %%
department_no = int(input('Enter the department number:'))
store_no = int(input("Enter the store number:"))
print()

query_data = df.query(f'Store == {store_no} and Dept == {department_no}')

sns.lineplot(data=query_data, x='Year', y='Weekly_Sales', color = 'g')

plt.title(f'stor {store_no} and department {department_no} weekly sales Trend')

plt.show()
# Out:
# Enter the department number:40
# Enter the store number:2
